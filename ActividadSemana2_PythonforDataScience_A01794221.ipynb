# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-jihidalgor/blob/main/ActividadSemana2_PythonforDataScience_A01794221.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TC4029.**
#
# **Jorge Iván Hidalgo Reyes.**
#
# **A01794221.**

# %% [markdown]
# ![EvidenciaM4IBM.PNG](data:image/png;base64,...)

# %% [markdown]
# # Curso IBM - Módulo 4.

# %% [markdown]
#  **Lab - Reading Files.**
#
# Se puede aplicar un método a un objeto para leer los datos de un archivo.
#
# El primer argumento es la ruta del archivo.
#
# El segundo argumento es el modo, los más comunes son: lectura (r) y escritura (w).
#
# Podemos utilizar el atributo de datos "name" para obtener el nombre del archivo.
#
# Siempre hay que cerrar el objeto archivo con el método "close". Otra manera es utilizar la sentencia 'with' para abrir el archivo ya que automáticamente cierra el archivo.
#
# El símbolo \n le indica a Python que debe comenzar una nueva línea.
#
# Podemos mostrar cada línea como un elemento de una lista utilizando el método "readlines". La primera línea corresponde al primer elemento de la lista. La segunda línea corresponde al segundo elemento de la lista, y así sucesivamente.

# %% [markdown]
# Download Data.

# %%
import urllib.request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
filename = 'Example1.txt'
urllib.request.urlretrieve(url, filename)

## Download Example file
# !wget -O /resources/data/Example1.txt https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt
# Out:
# /resources/data/Example1.txt: No such file or directory

# %% [markdown]
# Reading Text Files.

# %%
example1 = "Example1.txt"
file1 = open(example1, "r")

# %%
file1.name
# Out:
# 'Example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
FileContent = file1.read()
FileContent
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
type(FileContent)
# Out:
# str

# %%
file1.close()

# %% [markdown]
# A Better Way to Open a File.

# %%
with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
file1.closed
# Out:
# True

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
# Out:
# This

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
with open(example1, "r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
#
# This
# is line 2

# %%
with open(example1, "r") as file1:
    print("first line: " + file1.readline())
# Out:
# first line: This is line 1

# %%
with open(example1, "r") as file1:
    print(file1.readline(20)) # does not read past the end of line
    print(file1.read(20)) # Returns the next 20 chars
# Out:
# This is line 1
#
# This is line 2
# This

# %%
with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3

# %%
with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %%
FileasList[0]
# Out:
# 'This is line 1 \n'

# %%
FileasList[1]
# Out:
# 'This is line 2\n'

# %%
FileasList[2]
# Out:
# 'This is line 3'

# %% [markdown]
#  **Lab - Writing Files.**
#
# Se pueden escribir en archivos utilizando la función "open". El primer argumento es la ruta del archivo, e indicamos el parámetro 'w' para la escritura.
#
# Para crear un archivo de texto, podemos aplicar el método "write" para escribir datos en ese archivo.
#
# Utilizamos el método "write" para escribir datos en el archivo.
# El argumento es el texto que queremos introducir en el fichero.
#
# Podemos copiar un archivo a otro nuevo de la siguiente manera: Primero, leemos el fichero e interactuamos con él mediante el objeto de archivo "leer archivo". A continuación, se crea un nuevo fichero y utilizamos el objeto fichero "write file" para interactuar con él.
# El "ciclo for" toma una línea del objeto archivo leer archivo y la almacena en el archivo

# %% [markdown]
# Writing Files.

# %%
exmp2 = 'Example2.txt'
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A")

# %%
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A

# %%
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B

# %%
Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
with open('Example2.txt', 'w') as writefile:
    for line in Lines:
        print(line)
        writefile.write(line)
# Out:
# This is line A
#
# This is line B
#
# This is line C

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
with open('Example2.txt', 'w') as writefile:
    writefile.write("Overwrite\n")
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite

# %%
with open('Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line C\n")
    testwritefile.write("This is line D\n")
    testwritefile.write("This is line E\n")

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E

# %%
with open('Example2.txt', 'a+') as testwritefile:
    testwritefile.write("This is line E\n")
    print(testwritefile.read())

# %%
with open('Example2.txt', 'a+') as testwritefile:
    print("Initial Location: {}".format(testwritefile.tell()))
    
    data = testwritefile.read()
    if (not data):  #empty strings return false in python
            print('Read nothing') 
    else: 
            print(testwritefile.read())
            
    testwritefile.seek(0,0) # move 0 bytes from beginning.
    
    print("\nNew Location : {}".format(testwritefile.tell()))
    data = testwritefile.read()
    if (not data): 
            print('Read nothing') 
    else: 
            print(data)
    
    print("Location after read: {}".format(testwritefile.tell()) )
# Out:
# Initial Location: 70
# Read nothing
#
# New Location : 0
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line E
#
# Location after read: 70

# %%
with open('Example2.txt', 'r+') as testwritefile:
    data = testwritefile.readlines()
    testwritefile.seek(0,0) #write at beginning of file
   
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("finished\n")
    #Uncomment the line below
    #testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished
# is line D
# This is line E
# This is line E

# %% [markdown]
# Copy a File.

# %%
with open('Example2.txt','r') as readfile:
    with open('Example3.txt','w') as writefile:
          for line in readfile:
                writefile.write(line)

# %%
with open('Example3.txt','r') as testwritefile:
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished
# is line D
# This is line E
# This is line E

# %%
from random import randint as rnd

memReg = 'members.txt'
exReg = 'inactive.txt'
fee =('yes','no')

def genFiles(current,old):
    with open(current,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"

        for rowno in range(20):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[rnd(0,1)]))


    with open(old,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"
        for rowno in range(3):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[1]))


genFiles(memReg,exReg)

# %%
def cleanFiles(currentMem, exMem):    
    
    pass # Remove this line when done implementation

memReg = 'members.txt'
exReg = 'inactive.txt'
cleanFiles(memReg,exReg)


headers = "Membership No  Date Joined  Active  \n"
with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# Active Members:
#
#
# Membership No  Date Joined  Active
#     18771      2020-1-5     yes
#     15292      2017-1-9     no
#     63750      2019-5-11    yes
#     98237      2015-3-24    yes
#     28116      2016-4-22    no
#     85334      2019-7-2     yes
#     15874      2016-8-17    yes
#     88275      2020-3-19    no
#     53213      2019-2-18    yes
#     38188      2017-8-17    no
#     28435      2016-12-10   yes
#     67516      2015-11-17   no
#     16654      2018-4-21    yes
#     67853      2020-5-5     yes
#     28996      2018-4-22    no
#     76313      2017-2-25    yes
#     76135      2017-1-24    yes
#     74463      2018-6-4     yes
#     31260      2017-3-4     no
#     88193      2020-2-8     no
#
# Inactive Members:
#
#
# Membership No  Date Joined  Active
#     17163      2018-11-13   no
#     95803      2019-4-14    no
#     49349      2019-10-10   no

# %%
def testMsg(passed):
    if passed:
       return 'Test Passed'
    else :
       return 'Test Failed'

testWrite = "testWrite.txt"
testAppend = "testAppend.txt" 
passed = True

genFiles(testWrite,testAppend)

with open(testWrite,'r') as file:
    ogWrite = file.readlines()

with open(testAppend,'r') as file:
    ogAppend = file.readlines()

try:
    cleanFiles(testWrite,testAppend)
except:
    print('Error')

with open(testWrite,'r') as file:
    clWrite = file.readlines()

with open(testAppend,'r') as file:
    clAppend = file.readlines()
        
# checking if total no of rows is same, including headers

if (len(ogWrite) + len(ogAppend) != len(clWrite) + len(clAppend)):
    print("The number of rows do not add up. Make sure your final files have the same header and format.")
    passed = False
    
for line in clWrite:
    if  'no' in line:
        passed = False
        print("Inactive members in file")
        break
    else:
        if line not in ogWrite:
            print("Data in file does not match original file")
            passed = False
print ("{}".format(testMsg(passed)))
# Out:
# Inactive members in file
# Test Failed

# %% [markdown]
# **Loading Data with Pandas.**
#
# Podemos importar la biblioteca o una dependencia como pandas utilizando el siguiente comando import pandas as pd.
#
# Para poder cargar un archivo csv se utiliza la función incorporada de pandas "read csv".
#
# Un csv es un tipo de archivo típico utilizado para almacenar datos.
#
# Una de las formas en que pandas permite trabajar con datos es con un dataframe.
#
# Podemos utilizar el método "head" para examinar las 5 primeras filas de un dataframe.
#
# Un dataframe se compone de filas y columnas. Podemos crear un dataframe a partir de un diccionario. Las "keys corresponden a las etiquetas de las columnas. Los valores son listas que corresponden a las filas.
#
# "Keys" corresponden a las cabeceras de la tabla.
#
# "Values" son listas que corresponden a las filas.
#
# Una forma de acceder a los elementos únicos es el método ix.

# %%
import pandas as pd

songs = {'Album':['Thriller','Back in Black','The Dark Side of the Moon',\
         'The Bodyguard','Bat Out the Hell'],
         'Released':[1982, 1980, 1973, 1992, 1977],
         'Length':['00:42:19','00:42:11','00:42:49','00:57:44','00:46:33']}

songs_frame = pd.DataFrame(songs)
songs_frame
# Out:
#                        Album  Released    Length
# 0                   Thriller      1982  00:42:19
# 1              Back in Black      1980  00:42:11
# 2  The Dark Side of the Moon      1973  00:42:49
# 3              The Bodyguard      1992  00:57:44
# 4           Bat Out the Hell      1977  00:46:33

# %%
songs_frame.iloc[0,0]
# Out:
# 'Thriller'

# %%
import pandas as banana

df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})
df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %% [markdown]
# Working with and Saving Data with Pandas.

# %%
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool

# %%
df.to_csv("file.csv")

# %% [markdown]
#  **Lab - Loading Data and Viewing Data.**

# %%
import pandas as pd

csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
x = df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %% [markdown]
# Viewing Data and Accesing Data.

# %%
x = df['Length']
x
# Out:
# 0    0:42:19
# 1    0:42:11
# 2    0:42:49
# 3    0:57:44
# 4    0:46:33
# 5    0:43:08
# 6    1:15:54
# 7    0:40:01
# Name: Length, dtype: object

# %%
x = df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[1,0]
# Out:
# 'AC/DC'

# %%
df.iloc[0,2]
# Out:
# 1982

# %%
df.iloc[1,2]
# Out:
# 1980

# %%
df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
df.loc[0, 'Released']
# Out:
# 1982

# %%
df.iloc[0:2, 0:3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %% [markdown]
# Quiz on DataFrame.

# %%
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
df.iloc[1, 2]
# Out:
# 1980

# %%
new_index=['a','b','c','d','e','f','g','h']
df_new=df
df_new.index=new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'d', 'Artist']
# Out:
# a    Michael Jackson
# b              AC/DC
# c         Pink Floyd
# d    Whitney Houston
# Name: Artist, dtype: object

# %% [markdown]
# ![EvidenciaM4IBM2.PNG](data:image/png;base64,...)
